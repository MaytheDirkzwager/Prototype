# %%
"""
This file loads the data from the data directory and shows you how.
Feel free to change the contents of this file!
Do ensure these functions remain functional:
    - get_business(city, business_id)
    - get_reviews(city, business_id=None, user_id=None, n=10)
    - get_user(username)
"""

import os
import json
import random
import pandas as pd

DATA_DIR = "data"


def load_cities():
    """
    Finds all cities (all directory names) in ./data
    Returns a list of city names
    """
    return os.listdir(DATA_DIR)


def load(cities, data_filename):
    """
    Given a list of city names,
        for each city extract all data from ./data/<city>/<data_filename>.json
    Returns a dictionary of the form:
        {
            <city1>: [<entry1>, <entry2>, ...],
            <city2>: [<entry1>, <entry2>, ...],
            ...
        }
    """
    data = {}
    for city in cities:
        city_data = []
        with open(f"{DATA_DIR}/{city}/{data_filename}.json", "r") as f:
            for line in f:
                city_data.append(json.loads(line))
        data[city] = city_data
    return data


def get_business(city, business_id):
    """
    Given a city name and a business id, return that business's data.
    Returns a dictionary of the form:
        {
            name:str,
            business_id:str,
            stars:str,
            ...
        }
    """
    for business in BUSINESSES[city]:
        if business["business_id"] == business_id:
            return business
    raise IndexError(f"invalid business_id {business_id}")


def get_reviews(city, business_id=None, user_id=None, n=10):
    """
    Given a city name and optionally a business id and/or auser id,
    return n reviews for that business/user combo in that city.
    Returns a dictionary of the form:
        {
            text:str,
            stars:str,
            ...
        }
    """
    def should_keep(review):
        if business_id and review["business_id"] != business_id:
            return False
        if user_id and review["user_id"] != user_id:
            return False
        return True

    reviews = REVIEWS[city]
    reviews = [review for review in reviews if should_keep(review)]
    return random.sample(reviews, min(n, len(reviews)))


def get_user(username):
    """
    Get a user by its username
    Returns a dictionary of the form:
        {
            user_id:str,
            name:str,
            ...
        }
    """
    for city, users in USERS.items():
        for user in users:
            if user["name"] == username:
                return user
    raise IndexError(f"invalid username {username}")


CITIES = load_cities()
USERS = load(CITIES, "user")
BUSINESSES = load(CITIES, "business")
REVIEWS = load(CITIES, "review")
TIPS = load(CITIES, "tip")
CHECKINS = load(CITIES, "checkin")

df = pd.DataFrame(BUSINESSES['sun city'])

# %%
import pandas as pd

def search_engine(category, dataframe):
    """
    Get a category and a dataframe
    Returns a list of five best rated businesses in the given category
    """

    businesses = []
    
    

    for business in dataframe.index:
        if category in dataframe.loc[business]['categories']:
            businesses.append(dataframe.loc[business]['name'])

    ratings = dict()

    for item in businesses:
        for business in dataframe.index:
            if item == dataframe.loc[business]['name']:
                ratings[item] = dataframe.loc[business]['stars']


    return sorted(ratings.items(), key = lambda x: x[1], reverse = True)[:10]

# Test
search_engine('Restaurants', pd.DataFrame(BUSINESSES['westlake']))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e071a21d7b48> in <module>()
#      26
#      27 # Test
# ---> 28 search_engine('Restaurants', pd.DataFrame(BUSINESSES['westlake']))
#
# <ipython-input-6-e071a21d7b48> in search_engine(category, dataframe)
#      19     for item in businesses:
#      20         for business in dataframe.index:
# ---> 21             if item == dataframe.loc[business]['name']:
#      22                 ratings[item] = dataframe.loc[business]['stars']
#      23
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1910         # fall thru to straight lookup
#    1911         self._validate_key(key, axis)
# -> 1912         return self._get_label(key, axis=axis)
#    1913
#    1914
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     138             raise IndexingError('no slices here, handle elsewhere')
#     139
# --> 140         return self.obj._xs(label, axis=axis)
#     141
#     142     def _get_loc(self, key, axis=None):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3007             result = self._constructor_sliced(
#    3008                 new_values, index=self.columns,
# -> 3009                 name=self.index[loc], dtype=new_values.dtype)
#    3010
#    3011         else:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     272             else:
#     273                 data = _sanitize_array(data, index, dtype, copy,
# --> 274                                        raise_cast_failure=True)
#     275
#     276                 data = SingleBlockManager(data, index, fastpath=True)
#
# KeyboardInterrupt:

# %%
import pandas as pd

def search_engine(category, dataframe):
    """
    Gets a category and a dataframe
    Returns a list of five best rated businesses in the given category
    """

    # make a list of all businesses with given category
    businesses = [dataframe.loc[business]['name'] for business in dataframe.index 
                  if category in dataframe.loc[business]['categories']]
    
    ratings = dict()

    # get the number of stars for every business
    for item in businesses:
        for business in dataframe.index:
            if item == dataframe.loc[business]['name']:
                ratings[item] = dataframe.loc[business]['stars']

    # return the ten businesses with the highest number of stars 
    return sorted(ratings.items(), key = lambda x: x[1], reverse = True)[:10]

# test
search_engine('Restaurants', pd.DataFrame(BUSINESSES['westlake']))

# %%
test = pd.DataFrame(REVIEWS['sun city'])


for business in test.index:
    if 'Us5rN-zIUOWuzJWO3xFeLQ' == test.loc[business]['user_id']:
        print(test.loc[business]['text'])


# apP3CApEq6-z59tRLwEBYA

# %%
get_reviews('westlake', business_id=None, user_id='apP3CApEq6-z59tRLwEBYA', n=10)

# %%
df = pd.DataFrame(BUSINESSES['sun city'])

lijst = []
nieuw = set()


for attribute in df.attributes:
    if attribute != None:
        lijst.append(attribute)
        
        
for item in lijst:
    for x in item:
        nieuw.add(x)

nieuw

# %%
import pandas as pd

# Dataframe
df = pd.DataFrame(BUSINESSES['sun city'])

lijst = []
cat = set()

for categories in df.categories:
    lijst.append(categories)

for item in lijst:
    for x in item.split(','):
        cat.add(x.strip())

# %%
def similarity(x, y, df):
    
    for number in df.index:
        if x == df.loc[number]['name']:
            row_x = {item.strip() for item in df.loc[number]['categories'].split(',')}
        if y == df.loc[number]['name']:
            row_y = {item.strip() for item in df.loc[number]['categories'].split(',')}
    
    if  max(len(row_x), len(row_y)) == 0:
        return 0.0

    return len(row_x & row_y) / max(len(row_x), len(row_y))

# test
similarity('Subway', 'Colby Management', df)
# Out:
# 0.0

# %%
def similarity(x, y, df):
    """
    Gets business x, y, and a dataframe
    Returns similarity between business x and y
    """
    
    # get categories for business x and y
    for number in df.index:
        if x == df.loc[number]['name']:
            row_x = {item.strip() for item in df.loc[number]['categories'].split(',')}
        if y == df.loc[number]['name']:
            row_y = {item.strip() for item in df.loc[number]['categories'].split(',')}
    
    # return 0.0 if there aren't any categories
    if  max(len(row_x), len(row_y)) == 0:
        return 0.0

    # return similarity between x and y
    return len(row_x & row_y) / max(len(row_x), len(row_y))


def content_based(name, df): 
    """
    Gets name of business
    Returns list of ten most similar businesses
    """

    similarities = dict()
    
    # calculate similarities
    for item in df.index:
        similarities[df.loc[item]['name']] = similarity(name, df.loc[item]['name'], df)

    # return the ten businesses with the highest similarities 
    return sorted(similarities.items(), key = lambda x: x[1], reverse = True)[:10]


# test
lijst = content_based('KFC', df)
lijst
# Out:
# [('KFC', 1.0),
#  ('Subway', 0.5),
#  ("Filiberto's Mexican Food", 0.5),
#  ('Taco Bell', 0.5),
#  ('Dairy Queen', 0.5),
#  ('Jack in The Box', 0.5),
#  ('Jade Star', 0.5),
#  ('Pizza Hut', 0.5),
#  ("McDonald's", 0.4),
#  ("Arby's", 0.3333333333333333)]

# %%
def prediction(name):
    
    lijst = content_based(name)
    
    noemer = 0
    teller = 0
    
    for x,y in lijst:
        rating = df.loc[(x == df['name'])]['stars']
        teller += float(rating.values[0]) * y
        noemer += y
    
    
    
    return teller / noemer



prediction('Surface Savers')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-341b6dd98fc1> in <module>()
#      17
#      18
# ---> 19 prediction('Surface Savers')
#
# <ipython-input-3-341b6dd98fc1> in prediction(name)
#       1 def prediction(name):
#       2
# ----> 3     lijst = content_based(name)
#       4
#       5     noemer = 0
#
# NameError: name 'content_based' is not defined

# %%
import numpy as np

def get_rating(df, business):
    """
    Get dataframe, user_id and business_id
    Returns given rating 
    """
    
    # calculate rating for user and business
    rating = df.loc[(business == df['name'])]['stars']
    
    if rating.empty:
        return np.nan
    else:
        return float(rating.values[0])


get_rating(df, 'Surface Savers')
# Out:
# 5.0

# %%
business_names = {df.loc[item]['name'] for item in df.index}

predicted_ratings = pd.DataFrame(index = business_names, columns = ['rating', 'predicted rating'])

for x in predicted_ratings.index:
    predicted_ratings.loc[x]['rating'] = get_rating(df, x)
    predicted_ratings.loc[x]['predicted rating'] = prediction(x)
    


predicted_ratings
# Out:
#                                         rating predicted rating
# Starbucks                                    4            3.235
# China Olive Super Buffet                     2          3.07143
# Chase Bank                                 1.5          2.80157
# The Happy -r-ise Flowers                     3          3.60417
# Protect My Water                           4.5          3.95833
# Sun City Health & Rehabilitation Center      1          2.42857
# Arizona Art Supply                           4          3.45833
# Royal Cafe                                   3          3.46114
# Quick Mobile Repair                          5          4.33562
# The Wild Flower AZ                           5          3.55556
# Sun City Pet Lodge                         3.5          4.22478
# Jimichael's Restaurant                     3.5          3.56579
# Wildflower Dental                            4          4.38487
# Walman Eye Center - Sun City                 5           3.8856
# Mustard Seed Herbary                       2.5          3.71429
# Empire Blinds                                5          3.96196
# Rightway Pharmacy                          3.5          3.21947
# H & S Accounting, CPA                        5          3.35294
# BODY & BRAIN Yoga Tai Chi                    5          4.53086
# JJ's Barber Shop                           4.5            3.775
# Paradise RV Resort                         2.5          2.89655
# PRM Association Management                   5          2.88136
# Jade Star                                    3          2.41517
# Private Reserve Beef                       3.5          3.04462
# Coco's Bakery Restaurant                     3          3.22351
# Cutting Edge Window Tint                     4          3.94615
# CVS Pharmacy                               2.5          3.17181
# Van's Golf Shops                             5           3.7605
# Jack in The Box                              3          2.84211
# Sun City Florists                            4           3.5082
# ...                                        ...              ...
# Arizona Hot Dog                            4.5          3.59091
# US Post Office                             2.5          3.12329
# Ace Hardware                                 3          3.38298
# Quick Stop Title and Registration          4.5          3.97619
# The Book Trader                              4          3.78571
# Carrow's Family Restaurant                 2.5          3.39674
# Sun Camera                                 4.5          3.36364
# New England Clock Shop                     4.5          3.36364
# Sun City Dental & Denture Center             5          4.48327
# Line Thai Restaurant                         4          3.54545
# Sun City Mechanical                        3.5             3.85
# Domino's Pizza                             2.5          2.87879
# White Mountain Health Center               4.5          3.36678
# Zounds Hearing - Sun City                  2.5          2.93333
# Memo's Bistro                                4          3.24286
# The Speakeasy                              4.5              4.5
# Fix Auto Sun City                          4.5              3.5
# Mushkatel, Robbins & Becker                  3          2.96429
# Valley Estate Sale Company                 2.5          2.83099
# Wow Cafe                                   3.5              3.5
# Helvig Health Clinic                         5          4.27273
# National Floor Care                        2.5          3.83099
# The Oxygen Store                           1.5          2.91667
# The Val Barber Shop                        2.5           3.8125
# Consigning Women                           3.5          3.63636
# Fry's                                        3          2.83095
# New York West Pastry & Bake Shop             4          2.91793
# Benny's Burgers & BBQ                      4.5          3.65957
# Affordable Dentures                          3          3.73529
# Squeaky Clean Window Cleaning                5          4.38889
#
# [256 rows x 2 columns]

# %%
def mse(predicted_ratings):
    
    difference = [(row['rating'] - row['predicted rating']) ** 2 for index,row in predicted_ratings.iterrows()]
    print(difference)

    return sum(difference) / len(difference)
          
    
print(mse(predicted_ratings))
# Out:
# [0.5852249999999989, 1.1479591836734688, 1.6940933847620903, 0.3650173611111115, 0.2934027777777781, 2.040816326530612, 0.2934027777777776, 0.21265000402695444, 0.44140551698254804, 2.08641975308642, 0.5253083280917504, 0.004328254847645442, 0.14812278045219232, 1.2418953856993897, 1.4744897959183656, 1.0775342627599245, 0.07869514789080774, 2.7128027681660942, 0.22008840115835945, 0.5256250000000001, 0.15725326991676541, 4.488652686009764, 0.3420216055722792, 0.20737280351270063, 0.04995860291515592, 0.0028994082840237915, 0.45133024355637713, 1.5363498340512676, 0.02493074792243769, 0.2418704649287818, 2.3668639053254434, 0.2609877126654067, 0.0906831095041323, 2.5477071005917176, 0.5017361111111113, 0.0040977718178661065, 0.07245054425667108, 0.8049016649061944, 0.3635380622837366, 0.21556122448979687, 4.387326515704889, 0.0013154715562833674, 1.3348193601395901, 0.34027777777777796, 1.8418367346938778, 0.09812744955726514, 0.24999999999999956, 1.3960099801209007, 0.1724360815857514, 0.023749286296963754, 0.4576124567474046, 0.8919753086419757, 0.7932128906249984, 0.00026014568158167097, 1.1711390504785144, 0.140625, 0.4982698961937693, 0.5289256198347104, 2.9834710743801645, 0.9881306689342413, 0.4132653061224489, 3.2091535247845244, 0.11703601108033237, 0.7767882792301076, 0.07082466181061393, 0.04935549669421571, 0.32347656249999907, 1.24063795440051, 0.06785168831313391, 0.1038863465610267, 0.053254437869822514, 7.888609052210118e-31, 0.765625, 0.9147205785667327, 0.26701318970151855, 0.43707509585674315, 0.8167519803254304, 1.5220721235448071, 0.002300469159294887, 0.24999999999999867, 0.010161940686784648, 0.6542352167357395, 0.49946838017751344, 1.4588737933096747, 0.20782871972318354, 0.004959333465582212, 0.5129656683710732, 0.5186149476498099, 1.0149810648251274, 0.026649615920537096, 1.1225907029478464, 1.0000000000000018, 0.1227993279275328, 0.669421487603306, 1.5378455543574148, 0.1181640625, 0.8059901051671465, 0.46778279885012425, 0.43730489073881473, 1.61094674556213, 1.333076617890732, 0.19929846938775528, 1.1011188538781174, 0.2529556393560307, 0.0016796560064499101, 0.765625, 0.15707039071151283, 0.5789224952741024, 1.4035457827903794, 1.6071052142104305, 0.4379325259515569, 2.6044186661378808, 0.2621933517201328, 1.357899050611297, 2.6776859504132227, 0.4604591836734691, 0.918402777777778, 0.01959999999999991, 0.06602044753086429, 0.15884268010922076, 0.1451247165532883, 0.07562499999999996, 0.454776214862219, 0.008011354976375585, 0.03305785123966936, 0.028681061394380876, 2.8900000000000006, 0.46267618335952765, 0.7497025580011919, 0.32777810150923475, 1.0388313609467463, 0.054151338950199836, 0.25, 0.48779967846838523, 0.6824196597353499, 0.47928994082840143, 0.9212571747448968, 0.025069444444444127, 0.2866512647818942, 0.00850057844172845, 0.15725326991676541, 0.3084791250409018, 1.1479591836734697, 0.5318775609558196, 0.31306689342403654, 0.45661402986642435, 0.8139177693761819, 0.00020408163265308514, 1.117551020408163, 2.9834710743801645, 0.005917159763313635, 0.14868458299871232, 0.2632136105860115, 0.05328415657672491, 2.1229074473937004, 1.960000000000001, 0.47928994082840265, 0.47928994082840265, 0.34027777777777796, 0.03515625, 0.12674723496298398, 1.4027027870540887, 1.9214918368695884, 0.013249831789244902, 0.498413252273356, 0.006944444444444765, 1.118046224133294, 0.7585848074921943, 0.2943639655952918, 1.64810080350621, 0.24728999291115283, 0.885206863499004, 0.5393239087984052, 0.8231751728572125, 1.7093141289437597, 7.3842155009467536e-06, 0.6306228373702419, 4.997555194466388, 0.47968449931412843, 1.0291955471539602, 3.539500143636889, 0.9406662795761351, 0.17899408284023655, 0.09283447265625, 0.18367346938775514, 0.464876033057851, 0.000582639714625475, 0.0643247216971228, 0.1885387811634348, 0.29752066115702475, 3.6570848081776433, 0.09467455621301762, 0.01812130177514804, 4.132222520827733, 1.7914792899408276, 0.1155999999999996, 0.7017736226531237, 0.15581717451523555, 1.587350504 ...
# 0.7581566368237984

# %%
import numpy as np

def get_rating(df, user, business):
    """
    Get dataframe, user_id and business_id
    Returns given rating 
    """
    
    # calculate rating for user and business
    rating = df.loc[(business == df['business_id']) & (user == df['user_id'])]['stars']
    
    if rating.empty:
        return np.nan
    else:
        return float(rating.values[0])


businesses = pd.DataFrame(BUSINESSES['sun city'])[:10]

# make list of businesses 
business = [businesses.loc[item]['business_id'] for item in businesses.index]
# make list of users
users = [businesses.loc[item]['user_id'] for item in businesses.index]

# create empty utility matrix with users and businesses
utility = pd.DataFrame(0, index=users, columns=businesses)

for index in utility.index:
    for column in utility.columns:
        # add rating to utility matrix
        utility.loc[index, column] = get_rating(businesses, index, column)

# test
display(utility)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3108             try:
# -> 3109                 return libindex.get_value_box(s, key)
#    3110             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d92b247eb0f6> in <module>()
#      21 business = [businesses.loc[item]['business_id'] for item in businesses.index]
#      22 # make list of users
# ---> 23 users = [businesses.loc[item]['user_id'] for item in businesses.index]
#      24
#      25 # create empty utility matrix with users and businesses
#
# <ipython-input-12-d92b247eb0f6> in <listcomp>(.0)
#      21 business = [businesses.loc[item]['business_id'] for item in businesses.index]
#      22 # make list of users
# ---> 23 users = [businesses.loc[item]['user_id'] for item in businesses.index]
#      24
#      25 # create empty utility matrix with users and businesses
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3115                     raise InvalidIndexError(key)
#    3116                 else:
# -> 3117                     raise e1
#    3118             except Exception:  # pragma: no cover
#    3119                 raise e1
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3101         try:
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
#    3105             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'user_id'

# %%
display(df)
# Out:
#                                            address  \
# 0                           10659 Grand Ave, Ste 2
# 1                                 9010 N 103rd Ave
# 2                                  10661 Grand Ave
# 3                                  10101 Grand Ave
# 4                                12420 N 103rd Ave
# 5                         10474 W Thunderbird Blvd
# 6                                  10777 Grand Ave
# 7
# 8
# 9                                 18434 N 99th Ave
# 10                                15030 N 99th Ave
# 11                              9350 W Greenway Rd
# 12                             15626 Del Webb Blvd
# 13                                 10761 Grand Ave
# 14                                9009 N 103rd Ave
# 15                                  9801 W Bell Rd
# 16                         10050 W Bell Rd, Ste 12
# 17                       13000 N 103rd Ave, Ste 96
# 18                                  9805 W Bell Rd
# 19                      12630 N 103rd Ave, Ste 131
# 20                               12630 N 103rd Ave
# 21                        10001 W Bell Rd, Ste 102
# 22                                 10050 W Bell Rd
# 23                        10001 W Bell Rd, Ste 112
# 24                             15826 Del Webb Blvd
# 25                                 10109 Grand Ave
# 26                                 13764 W Bell Rd
# 27                                9433 N 107th Ave
# 28                                15458 N 99th Ave
# 29                        10001 W Bell Rd, Ste 122
# ..                                             ...
# 229                       10749 W Grand Ave, Ste 8
# 230                       10001 W Bell Rd, Ste 146
# 231                        9421 W Bell Rd, Ste 101
# 232                                 9827 W Bell Rd
# 233                                10050 W Bell Rd
# 234                                 9855 W Bell Rd
# 235                                10050 W Bell Rd
# 236                        10301 W Spanish Moss Ln
# 237                            10026 W Santa Fe Dr
# 238
# 239                            10014 W Santa Fe Dr
# 240  10147 Grand Ave, Ste B2, Sun City Dental Care
# 241                  17220 N Boswell Blvd, Ste 140
# 242                          9069 W Thunderbird Rd
# 243                               13606 N 99th Ave
# 244                              13002 N 107th Ave
# 245                        10050 W Bell Rd, Ste 22
# 246
# 247                                 9857 W Bell Rd
# 248                               15434 N 99th Ave
# 249                      18700 N 107th Ave, Ste 32
# 250                             9980 W Santa Fe Dr
# 251                                10801 Grand Ave
# 252                                 9835 W Bell Rd
# 253                             11819 W Harmony Ln
# 254                               17032 N 99th Ave
# 255                   10451 W Palmeras Dr, Ste 101
# 256                               15462 N 99th Ave
# 257
# 258                           19218 N Carnation Dr
#
#                                             attributes  \
# 0    {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 1    {'BikeParking': 'True', 'RestaurantsPriceRange...
# 2    {'WiFi': ''no'', 'RestaurantsReservations': 'F...
# 3    {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 4               {'BusinessAcceptsCreditCards': 'True'}
# 5    {'ByAppointmentOnly': 'True', 'AcceptsInsuranc...
# 6    {'WiFi': 'u'no'', 'RestaurantsTakeOut': 'True'...
# 7    {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 8                                                 None
# 9                                                 None
# 10              {'BusinessAcceptsCreditCards': 'True'}
# 11   {'GoodForKids': 'False', 'BikeParking': 'True'...
# 12                                                None
# 13              {'BusinessAcceptsCreditCards': 'True'}
# 14   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 15   {'WheelchairAccessible': 'True', 'OutdoorSeati...
# 16   {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 17                       {'ByAppointmentOnly': 'True'}
# 18   {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 19   {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 20   {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 21   {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 22   {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 23   {'BusinessParking': '{'garage': False, 'street...
# 24             {'BusinessAcceptsCreditCards': 'False'}
# 25   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 26                                                None
# 27   {'GoodForKids': 'True', 'BikeParking': 'True',...
# 28                      {'ByAppointmentOnly': 'False'}
# 29              {'BusinessAcceptsCreditCards': 'True'}
# ..                                                 ...
# 229                                               None
# 230  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 231  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 232  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 233  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...
# 234  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 235  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 236                                               None
# 237                                               None
# 238                                               None
# 239             {'BusinessAcceptsCreditCards': 'True'}
# 240                     {'ByAppointmentOnly': 'False'}
# 241                     {'ByAppointmentOnly': 'False'}
# 242  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 243                                               None
# 244  {'RestaurantsPriceRange2': '3', 'BikeParking':...
# 245  {'RestaurantsPriceRange2': '1', 'RestaurantsDe...
# 246  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 247                                               None
# 248  {'BusinessParking': '{'garage': False, 'street...
# 249                    {'RestaurantsTakeOut': 'False'}
# 250  {'BusinessParking': '{'garage': False, 'street...
# 251  {'BusinessParking': '{'garage': False, 'street...
# 252  {'RestaurantsPriceRange2': '3', 'BusinessAccep...
# 253  {'GoodForKids': 'True', 'BikeParking': 'True',...
# 254  {'HasTV': 'True', 'RestaurantsGoodForGroups': ...
# 255                                               None
# 256  {'WiFi': ''no'', 'OutdoorSeating': 'True', 'Go...
# 257  {'ByAppointmentOnly': 'True', 'RestaurantsPric...
# 258  {'ByAppointmentOnly': 'False', 'BikeParking': ...
#
#                 business_id  \
# 0    ol2r325YnfuHcq7yeO3vdg
# 1    GmIUJmlwf3fJxFm79EZNgw
# 2    O4TYqnhpXpyrgJBkucaeaw
# 3    rIhu4bA2CmSicOSJmTpGug
# 4    2y2d1wJrZAhHI2J7o2ndtg
# 5    _oUWOp4DIxmdBKxZ-uC2NQ
# 6    8EIZAb0knT2u_z2gIxllXw
# 7    P8AV927sZLwWzbTtEY-apA
# 8    V8e5QPOcULM-h8nTcsRH6g
# 9    Y35ovjGFEe9i82-XIVa-FQ
# 10   S9BSFX03TBqAHFF1M4c08g
# 11   uMvfhT3plydwp5f28wk7YA
# 12   JaTMTpzALqsL2lesFRrQkw
# 13   IoMUTHajJFgJD0Jqqqt0PQ
# 14   tnEotbnOgVcBxXD3PtPm7Q
# 15   Q1itFc-ptu1hGIAMWU0qBw
# 16   TL-D_z9E1eKJQqSioemFfw
# 17   W9qZHec23yJRFf_R91o0TA
# 18   PNzir9TtJAD7U41GwR98-w
# 19   UL0FoeGT0marq0RG70G-YQ
# 20   zh_AIXt_wELJJLPfTmJcPw
# 21   hZoIxNxron8LjWve8NIHoQ
# 22   yOXa1_7QOMa7kquRby7zMA
# 23   aodZ-VnWrGd26yeLFKRieA
# 24   RNkB4XsekPi5HPxT7vN2Dg
# 25   RcXZAs0GU1_f-IulNtyuMw
# 26   nsDDx67UwXJvbkNdoXHmIQ
# 27   FP1W3vmQDg9vk3IeWdSccA
# 28   IP7CA2C8TMcBTv3DvWHWcg
# 29   x2U_TzthfTvtyZ1_u36Z9w
# ..                      ...
# 229  6kpF5FQz6k9CGmocM2Hl2A
# 230  qYJGANkrRrI-aqfW1BaHuw
# 231  OWV8yrZsQhMDFl2l0l9H1w
# 232  VpZYWGueVqC1A8PN3btB3w
# 233  o3Wj6ohtPnvOJ9l0d_FT9A
# 234  4x242zFC9YKuos3ZeX01wg
# 235  6nXGWiwT6L6bZ0N68tFCEQ
# 236  FWle3DWp1l1dIVj3rRDPew
# 237  WOUO_lu5DUhWM_3eh9es4w
# 238  ELPhr2CAhRub44Vdwc7uyw
# 239  sWm7MzyzqfifbBysBCh44Q
# 240  zp8EcaN9tvG8C_q5cVOtKg
# 241  Pkf9nJuBI6_LJGPac-J7mA
# 242  YlQjjoZqSlgZBwWgOaACZQ
# 243  jLdy5xNLk1QvFi5uWliL2w
# 244  VezMq5tZxqZf80MDrlLQLw
# 245  CdqDmKlSVrTBigSZnpQYug
# 246  LRlUBt7ubV6ZuOlk0hnawA
# 247  UXrbMbgg3VZ5hkPoCgs67A
# 248  ZYQYgXPPjAwA0AtY8ndXmw
# 249  2CMFcgwzXkwszGqwkZ0J4A
# 250  RXhMtim4RXqUNbw9KeRMwQ
# 251  aLJrD7AwySfSvYx9fNvJRg
# 252  AJDIJHeA9j8OvHfecwS8Kg
# 253  1GLJHF1aIrKujEmfEBHPYQ
# 254  6CpAWkTcqqNtGAfOsPeFUw
# 255  j3WPutOh9WvuR9ol2Tjabw
# 256  DGOWO87MQmA4-2swRLK2DA
# 257  12_HZrcGfQny55r-bILQWQ
# 258  o1nRrhcoKS9XvBM9t4SOnw
#
#                                             categories      city  \
# 0                   Sandwiches, Fast Food, Restaurants  Sun City
# 1                                 Shopping, Pawn Shops  Sun City
# 2    Chicken Wings, Fast Food, Chicken Shop, Restau...  Sun City
# 3                          Restaurants, Food, Bakeries  Sun City
# 4    Venues & Event Spaces, Local Services, Event P...  Sun City
# 5    Doctors, Orthopedists, Neurologist, Health & M...  Sun City
# 6                      Restaurants, Mexican, Fast Food  Sun City
# 7    Contractors, Home Services, Home & Garden, Sho...  Sun City
# 8    Home Services, Heating & Air Conditioning/HVAC...  Sun City
# 9                           Medical Supplies, Shopping  Sun City
# 10                             Automotive, Auto Repair  Sun City
# 11   Event Planning & Services, Golf, Active Life, ...  Sun City
# 12                        Public Services & Government  Sun City
# 13       Funeral Services & Cemeteries, Local Services  Sun City
# 14                 Beauty & Spas, Barbers, Hair Salons  Sun City
# 15   Bakeries, Food, Breakfast & Brunch, American (...  Sun City
# 16                  Restaurants, Sandwiches, Fast Food  Sun City
# 17        Internal Medicine, Doctors, Health & Medical  Sun City
# 18                                   Restaurants, Thai  Sun City
# 19   Health & Medical, Specialty Food, Food, Nutrit...  Sun City
# 20   Arts & Crafts, Cards & Stationery, Event Plann...  Sun City
# 21   Water Purification Services, Home Services, Pl...  Sun City
# 22                             Thrift Stores, Shopping  Sun City
# 23   Sports Wear, Bowling, Shopping, Active Life, S...  Sun City
# 24   Cremation Services, Mortuary Services, Funeral...  Sun City
# 25                  Antiques, Shopping, Auction Houses  Sun City
# 26   Pet Services, Pet Stores, Pet Groomers, Pet Tr...  Sun City
# 27   Active Life, American (Traditional), Arts & En...  Sun City
# 28   Health & Medical, Automotive, Mobility Equipme...  Sun City
# 29                Local Services, Sewing & Alterations  Sun City
# ..                                                 ...       ...
# 229                   Pet Services, Pet Groomers, Pets  Sun City
# 230            Shopping, Photography Stores & Services  Sun City
# 231  Gold Buyers, Financial Services, Jewelry, Pawn...  Sun City
# 232                             Barbers, Beauty & Spas  Sun City
# 233                               Chinese, Restaurants  Sun City
# 234  Home Services, Tiling, Carpet Installation, Ca...  Sun City
# 235                                 Restaurants, Greek  Sun City
# 236        Bridal, Flowers & Gifts, Florists, Shopping  Sun City
# 237  Pet Adoption, Pet Sitting, Veterinarians, Pets...  Sun City
# 238                  Veterinarians, Pets, Pet Services  Sun City
# 239  Oil Change Stations, Auto Repair, Tires, Auto ...  Sun City
# 240  Cosmetic Dentists, Dentists, General Dentistry...  Sun City
# 241    Home Services, Real Estate, Property Management  Sun City
# 242  Eyewear & Opticians, Insurance, Urgent Care, D...  Sun City
# 243                         Hair Salons, Beauty & Spas  Sun City
# 244  Sewing & Alterations, Local Services, Dry Clea...  Sun City
# 245         Chicken Wings, Italian, Restaurants, Pizza  Sun City
# 246  Real Estate, Shopping, Estate Liquidation, Thr...  Sun City
# 247                              Professional Services  Sun City
# 248  Arts & Crafts, Embroidery & Crochet, Screen Pr...  Sun City
# 249    Olive Oil, Herbs & Spices, Specialty Food, Food  Sun City
# 250  Medical Supplies, Local Services, Shopping, Ac...  Sun City
# 251                      Restaurants, Chinese, Buffets  Sun City
# 252                                  Watches, Shopping  Sun City
# 253  Active Life, ATV Rentals/Tours, Trailer Rental...  Sun City
# 254  Steakhouses, Sandwiches, American (Traditional...  Sun City
# 255    Property Management, Real Estate, Home Services  Sun City
# 256                  Mediterranean, Greek, Restaurants  Sun City
# 257  Movers, Appliances & Repair, Fitness/Exercise ...  Sun City
# 258  Permanent Makeup, Tattoo, Piercing, Beauty & Spas  Sun City
#
#                                                  hours  is_open   latitude  \
# 0                                                 None        1  33.601360
# 1    {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  33.566430
# 2    {'Monday': '9:30-22:0', 'Tuesday': '9:30-22:0'...        1  33.602088
# 3    {'Tuesday': '6:0-18:0', 'Wednesday': '6:0-18:0...        1  33.598696
# 4    {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.598180
# 5                                                 None        1  33.605581
# 6    {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  33.603017
# 7    {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.690766
# 8    {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  33.682571
# 9    {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...        1  33.652244
# 10   {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.621616
# 11   {'Monday': '6:30-17:0', 'Tuesday': '6:30-17:0'...        1  33.624195
# 12                                                None        1  33.626355
# 13   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  33.602979
# 14                                                None        1  33.566147
# 15   {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...        1  33.637517
# 16                                                None        1  33.639611
# 17                                                None        1  33.601850
# 18   {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...        1  33.637504
# 19   {'Tuesday': '10:0-14:0', 'Wednesday': '10:0-14...        1  33.598799
# 20   {'Monday': '7:0-19:0', 'Tuesday': '7:0-19:0', ...        0  33.598882
# 21   {'Monday': '9:0-16:0', 'Tuesday': '9:0-16:0', ...        1  33.637239
# 22   {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...        1  33.639611
# 23   {'Monday': '10:0-17:0', 'Tuesday': '9:0-14:30'...        1  33.637293
# 24   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  33.628345
# 25   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  33.598655
# 26   {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...        1  33.640815
# 27   {'Monday': '6:0-17:0', 'Tuesday': '6:0-17:0', ...        1  33.569445
# 28                                                None        1  33.623713
# 29                                                None        1  33.637239
# ..                                                 ...      ...        ...
# 229  {'Tuesday': '7:30-15:0', 'Wednesday': '7:30-15...        1  33.599243
# 230                                               None        1  33.636980
# 231  {'Monday': '10:0-19:0', 'Tuesday': '10:0-19:0'...        1  33.637693
# 232                                               None        1  33.637124
# 233                                               None        0  33.639637
# 234  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  33.637133
# 235                                               None        1  33.639611
# 236  {'Monday': '8:0-19:0', 'Tuesday': '8:0-19:0', ...        1  33.597507
# 237  {'Monday': '7:30-18:0', 'Tuesday': '7:30-17:0'...        1  33.599429
# 238                                               None        1  33.682571
# 239  {'Monday': '0:0-0:0', 'Tuesday': '7:30-17:0', ...        1  33.598981
# 240  {'Tuesday': '8:0-14:0', 'Wednesday': '8:0-13:0...        1  33.599052
# 241  {'Monday': '8:0-15:0', 'Tuesday': '8:0-15:0', ...        1  33.639733
# 242  {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...        1  33.609344
# 243                                               None        1  33.607569
# 244  {'Monday': '6:0-17:0', 'Tuesday': '6:0-17:0', ...        1  33.601610
# 245                                               None        1  33.639530
# 246  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  33.638182
# 247  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  33.637138
# 248  {'Monday': '0:0-0:0', 'Tuesday': '9:0-14:0', '...        1  33.622856
# 249  {'Monday': '9:0-14:0', 'Tuesday': '9:0-14:0', ...        1  33.653197
# 250                                               None        1  33.599375
# 251                                               None        0  33.603332
# 252                                               None        1  33.637145
# 253  {'Monday': '0:0-0:0', 'Tuesday': '9:0-17:0', '...        1  33.676734
# 254  {'Monday': '7:0-22:0', 'Tuesday': '7:0-22:0', ...        1  33.639263
# 255                                               None        1  33.640769
# 256                                               None        1  33.621473
# 257  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.597530
# 258  {'Monday': '13:0-1:0', 'Tuesday': '13:0-1:0', ...        1  33.582838
#
#       longitude                                               name  \
# 0   -112.287538                                             Subway
# 1   -112.281652                                       Phoenix Pawn
# 2   -112.289520                                                KFC
# 3   -112.277505                   New York West Pastry & Bake Shop
# 4   -112.281573                   Menke Funeral & Cremation Center
# 5   -112.283948                      The CORE Institute - Peoria 2
# 6   -112.292999                           Filiberto's Mexican Food
# 7   -112.315382                                     Surface Savers
# 8   -112.303973                      Todd Edwards Air Conditioning
# 9   -112.279337                                   The Oxygen Store
# 10  -112.269476                       Greenway Family Auto Service
# 11  -112.260002                             Palmbrook Country Club
# 12  -112.287786                                        Epcor Water
# 13  -112.292451                           Palm Valley Funeral Home
# 14  -112.280618                                The Val Barber Shop
# 15  -112.270777                           Coco's Bakery Restaurant
# 16  -112.276124                                             Subway
# 17  -112.281712                                  Vasireddy Rama MD
# 18  -112.270825                               Line Thai Restaurant
# 19  -112.281922                               Mustard Seed Herbary
# 20  -112.281669                           The Happy -r-ise Flowers
# 21  -112.275460                                   Protect My Water
# 22  -112.276124                            Penny -Wise Thrift Shop
# 23  -112.276666                        Vital Signs Bowling Proshop
# 24  -112.289327  Sunland Memorial Park  Mortuary & Cremation Ce...
# 25  -112.278378                                  Auction Ron Brunk
# 26  -112.356712                                           PetSmart
# 27  -112.286243                              Sun City Country Club
# 28  -112.271139                                 Southwest Mobility
# 29  -112.275460                                    Ester Tailoring
# ..          ...                                                ...
# 229 -112.279268                            Precious Paws Pet Salon
# 230 -112.274774                                         Sun Camera
# 231 -112.262758                                    Arizona EZ-Pawn
# 232 -112.271158                                    Campana Barbers
# 233 -112.275864                Golden Star Chinese Food Restaurant
# 234 -112.272041                                      Floors n More
# 235 -112.276124                                      Romen's Gyros
# 236 -112.271911                                 The Wild Flower AZ
# 237 -112.274960                           Sun City Animal Hospital
# 238 -112.303973                                      Paws at Peace
# 239 -112.274437                              Sun City Auto Service
# 240 -112.279256                                Joseph H Chang, DDS
# 241 -112.279221                                   Colby Management
# 242 -112.254329                                              Cigna
# 243 -112.269020                                Valley Beauty Salon
# 244 -112.290442                                  Sun City Cleaners
# 245 -112.276610                                          Pizza Hut
# 246 -112.270476                         Valley Estate Sale Company
# 247 -112.272118                                  Sun Valley Quilts
# 248 -112.271345                     Can-Do Engraving & Specialties
# 249 -112.291213                                Country Spice Shack
# 250 -112.273702                                   Sunshine Service
# 251 -112.294278                             New China Super Buffet
# 252 -112.271385                             New England Clock Shop
# 253 -112.314947                            Sand Highway RV Rentals
# 254 -112.275256                                             Arby's
# 255 -112.279663                         Kinney Management Services
# 256 -112.269788                                      Sunset Bistro
# 257 -112.271835                                        Ace Fitness
# 258 -112.170102                                 Traditional Tattoo
#
#     postal_code  review_count  stars state
# 0         85351            13    2.0    AZ
# 1         85351             3    5.0    AZ
# 2         85351            25    1.5    AZ
# 3         85351           143    4.0    AZ
# 4         85351             6    4.5    AZ
# 5         85351             3    2.5    AZ
# 6         85351            43    2.5    AZ
# 7         85373             5    5.0    AZ
# 8         85373             4    3.5    AZ
# 9         85373            19    1.5    AZ
# 10        85351            19    3.5    AZ
# 11        85351             6    3.0    AZ
# 12        85351            36    1.5    AZ
# 13        85351            12    3.5    AZ
# 14        85351             3    2.5    AZ
# 15        85351            37    3.0    AZ
# 16        85351             5    3.0    AZ
# 17        85351             3    1.0    AZ
# 18        85351           215    4.0    AZ
# 19        85351             3    2.5    AZ
# 20        85351             4    3.0    AZ
# 21        85351             6    4.5    AZ
# 22        85351            11    3.0    AZ
# 23        85351             6    4.5    AZ
# 24        85351             5    4.0    AZ
# 25        85351             9    3.5    AZ
# 26        85374            30    3.5    AZ
# 27        85351             9    4.0    AZ
# 28        85351             7    4.0    AZ
# 29        85351             9    4.5    AZ
# ..          ...           ...    ...   ...
# 229       85351            12    4.5    AZ
# 230       85351            11    4.5    AZ
# 231       85351            10    4.0    AZ
# 232       85351             5    3.5    AZ
# 233       85351             5    2.5    AZ
# 234       85351            16    4.5    AZ
# 235       85351             4    2.0    AZ
# 236       85373             3    5.0    AZ
# 237       85351            25    4.5    AZ
# 238       85373             7    5.0    AZ
# 239       85351            10    4.0    AZ
# 240       85351             5    5.0    AZ
# 241       85351             4    2.0    AZ
# 242       85351             6    1.0    AZ
# 243       85351             3    4.5    AZ
# 244       85351             8    1.5    AZ
# 245       85351             7    1.5    AZ
# 246       85372             9    2.5    AZ
# 247       85351             4    4.5    AZ
# 248       85351             3    5.0    AZ
# 249       85373             4    5.0    AZ
# 250       85351             3    5.0    AZ
# 251       85351             5    1.5    AZ
# 252       85351            17    4.5    AZ
# 253       85373            27    5.0    AZ
# 254       85373            16    3.5    AZ
# 255       85373             3    1.0    AZ
# 256       85351            18    4.5    AZ
# 257       85373             3    3.5    AZ
# 258       85373             7    1.5    AZ
#
# [259 rows x 14 columns]

# %%
reviews = pd.DataFrame(REVIEWS['sun city'])

# business_ids = {reviews.loc[item]['business_id'] for item in reviews.index}
# user_ids = {reviews.loc[item]['user_id'] for item in reviews.index}

def pivot_ratings(df):
    
    business_ids = {df.loc[item]['business_id'] for item in df.index}
    user_ids = {df.loc[item]['user_id'] for item in df.index}
    
    matrix = pd.DataFrame(index = list(business_ids), columns = list(user_ids))
    
    for x in business_ids:
        for y in user_ids:
            matrix.loc[x, y] = get_rating(df, y, x)
            
            

    return matrix


pivot_ratings(reviews[:10])
# Out:
#                        oDexYEBOZEPBGJ5_e48lZw 6xGTlUEbAe0ZgEP7T11r2Q  \
# rIhu4bA2CmSicOSJmTpGug                    NaN                    NaN
# S9BSFX03TBqAHFF1M4c08g                    NaN                    NaN
# PNzir9TtJAD7U41GwR98-w                      1                      4
# TL-D_z9E1eKJQqSioemFfw                    NaN                    NaN
#
#                        Z1wf19FVzvR57O0T-CdBYw yTZC-agO3gknzsL1A7LOIQ  \
# rIhu4bA2CmSicOSJmTpGug                      3                    NaN
# S9BSFX03TBqAHFF1M4c08g                    NaN                    NaN
# PNzir9TtJAD7U41GwR98-w                    NaN                    NaN
# TL-D_z9E1eKJQqSioemFfw                    NaN                      5
#
#                        liWnObQxCckRGAyFbaI7oQ gKX5BAYV81HOtBqBvhuQvg  \
# rIhu4bA2CmSicOSJmTpGug                    NaN                    NaN
# S9BSFX03TBqAHFF1M4c08g                    NaN                    NaN
# PNzir9TtJAD7U41GwR98-w                      5                      5
# TL-D_z9E1eKJQqSioemFfw                    NaN                    NaN
#
#                        DYJdxkfsqe2mSYFdKAIkBA DAIpUGIsY71noX0wNuc27w  \
# rIhu4bA2CmSicOSJmTpGug                    NaN                    NaN
# S9BSFX03TBqAHFF1M4c08g                    NaN                    NaN
# PNzir9TtJAD7U41GwR98-w                      5                      5
# TL-D_z9E1eKJQqSioemFfw                    NaN                    NaN
#
#                        HX4IwDr-uvlXVE21lXbrjg x-rMRSFlYHr_zTa3ah4MoA
# rIhu4bA2CmSicOSJmTpGug                    NaN                      2
# S9BSFX03TBqAHFF1M4c08g                      5                    NaN
# PNzir9TtJAD7U41GwR98-w                    NaN                    NaN
# TL-D_z9E1eKJQqSioemFfw                    NaN                    NaN

# %%
def predict_ratings(similarity, utility, to_predict):
    """Predicts the predicted rating for the input test data.
    
    Arguments:
    similarity -- a dataFrame that describes the similarity between items
    utility    -- a dataFrame that contains a rating for each user (columns) and each movie (rows). 
                  If a user did not rate an item the value np.nan is assumed. 
    to_predict -- A dataFrame containing at least the columns movieId and userId for which to do the predictions
    """
    # copy input (don't overwrite)
    ratings_test_c = to_predict.copy()
    # apply prediction to each row
    ratings_test_c['predicted rating'] = to_predict.apply(lambda row: predict_ids(similarity, utility, row['userId'], row['movieId']), axis=1)
    return ratings_test_c

### Helper functions for predict_ratings_item_based ###

def predict_ids(similarity, utility, userId, itemId):
    # select right series from matrices and compute
    if userId in utility.columns and itemId in similarity.index:
        return predict_vectors(utility.loc[:,userId], similarity[itemId])
    return 0

def predict_vectors(user_ratings, similarities):
    # select only movies actually rated by user
    relevant_ratings = user_ratings.dropna()
    
    # select corresponding similairties
    similarities_s = similarities[relevant_ratings.index]
    
    # select neighborhood
    similarities_s = similarities_s[similarities_s > 0.0]
    relevant_ratings = relevant_ratings[similarities_s.index]
    
    # if there's nothing left return a prediction of 0
    norm = similarities_s.sum()
    if(norm == 0):
        return 0
    
    # compute a weighted average (i.e. neighborhood is all) 
    return np.dot(relevant_ratings, similarities_s)/norm

# %%
from data import CITIES, BUSINESSES, USERS, REVIEWS, TIPS, CHECKINS

import random
import pandas as pd

# helperfunction for recommend
def similarity(x, y, df):
    """
    Gets business x, y, and a dataframe
    Returns similarity between business x and y
    """
   
    categories_x = set()
    categories_y = set()

    # get categories for business x and y
    for number in df.index:
        if x == df.loc[number]['business_id']:
            categories_x = {item.strip() for item in df.loc[number]['categories'].split(',')}
        if y == df.loc[number]['business_id']:
            categories_y = {item.strip() for item in df.loc[number]['categories'].split(',')}
    
    # return 0.0 if there aren't any categories
    if  max(len(categories_x), len(categories_y)) == 0:
        return 0.0
    
    # return similarity between x and y
    return len(categories_x & categories_y) / max(len(categories_x), len(categories_y))


def recommend(business_id, city=None, n=10):
    """
    Returns n recommendations as a list of dicts.
    Takes in a business_id
    Optionally takes in a city.
    A recommendation is a dictionary in the form of:
        {
            business_id:str
            stars:str
            name:str
            city:str
            address:str
        }
    """
    
    # choose random city if no city is given
    if not city:
        city = random.choice(CITIES)
              
    # create dataframe with businesses 
    df = pd.DataFrame(BUSINESSES[city])
        
    similarities = dict()
    
    # calculate similarities
    for item in df.index:
        if not business_id == df.loc[item]['business_id']:
            similarities[df.loc[item]['business_id']] = similarity(business_id, df.loc[item]['business_id'], df)
    
    # create list of similarities for top n recommended businesses
    similarity_list = sorted(similarities.items(), key = lambda x: x[1], reverse = True)[:n]
    
    recommendation = []
    required_values = ['business_id', 'stars', 'name', 'city', 'address']
    
    # create a dictionary with usefull data for every recommended business
    for x, y in similarity_list:
        
        dictionary = dict()
                
        for item in df.index:
            if df.loc[item]['business_id'] == x:
                for value in required_values:
                    dictionary[value] = str(df.loc[item][value])        
        
        recommendation.append(dictionary)
        
    return recommendation


# test
recommend(business_id = 'ol2r325YnfuHcq7yeO3vdg')
# Out:
# [{'business_id': '-MsRvdPnuw6QuLn5Vxjruw',
#   'stars': '5.0',
#   'name': "Brian's Furniture",
#   'city': 'Westlake',
#   'address': '30808 Center Ridge Rd'},
#  {'business_id': 'C_oejk3EzfsxP7-owQDkbQ',
#   'stars': '4.0',
#   'name': 'Camp Bow Wow Westlake',
#   'city': 'Westlake',
#   'address': '863 Bradley Rd'},
#  {'business_id': 'nYvBZYg9rfqWFTYuxSVMdw',
#   'stars': '4.0',
#   'name': 'Cantina Laredo',
#   'city': 'Westlake',
#   'address': '2004 Crocker Rd'},
#  {'business_id': '0ZN2MfHyjNIkCx7qJvVhDg',
#   'stars': '2.5',
#   'name': 'SB Eightyone',
#   'city': 'Westlake',
#   'address': '24481 Detroit Rd'},
#  {'business_id': 'VZKWW2zQbk-rxwpAcque8w',
#   'stars': '3.0',
#   'name': 'Kish L Stephen, MD',
#   'city': 'Westlake',
#   'address': '26410 Center Ridge Rd'},
#  {'business_id': 'K5iqS0JXnKFFujZHIWQsag',
#   'stars': '3.5',
#   'name': 'Dover Gardens Tavern',
#   'city': 'Westlake',
#   'address': '27402 Detroit Rd'},
#  {'business_id': 'i7lFu1-iadoXW5Hn-JWaeg',
#   'stars': '3.5',
#   'name': 'Holiday Inn Express & Suites Cleveland West - Westlake',
#   'city': 'Westlake',
#   'address': '30500 Clemens Rd'},
#  {'business_id': '2lcK3d4K7FU6O8wXdWzOmA',
#   'stars': '4.0',
#   'name': 'Cabin Club',
#   'city': 'Westlake',
#   'address': '30651 Detroit Rd'},
#  {'business_id': 'OD88wvH-9LxM_Gz4oHOIDg',
#   'stars': '4.5',
#   'name': 'Westlake Dental Associates',
#   'city': 'Westlake',
#   'address': '25575 Center Ridge Rd'},
#  {'business_id': 'mW28NmePxX7pZv8lCv7v2Q',
#   'stars': '5.0',
#   'name': 'Convenient Food Mart',
#   'city': 'Westlake',
#   'address': '27112 Detroit Rd'}]

# %%
from data import CITIES, BUSINESSES, USERS, REVIEWS, TIPS, CHECKINS

import random
import pandas as pd

# helperfunction for recommend
def similarity(x, y, df):
    """
    Gets business x, y, and a dataframe
    Returns similarity between business x and y
    """
   
    categories_x = set()
    categories_y = set()

    # get categories for business x and y
    for number in df.index:
        if x == df.loc[number]['business_id']:
            categories_x = {item.strip() for item in df.loc[number]['categories'].split(',')}
        if y == df.loc[number]['business_id']:
            categories_y = {item.strip() for item in df.loc[number]['categories'].split(',')}
    
    # return 0.0 if there aren't any categories
    if  max(len(categories_x), len(categories_y)) == 0:
        return 0.0
    
    # return similarity between x and y
    return len(categories_x & categories_y) / max(len(categories_x), len(categories_y))


def recommend(business_id, city=None, n=10):
    """
    Returns n recommendations as a list of dicts.
    Takes in a business_id
    Optionally takes in a city.
    A recommendation is a dictionary in the form of:
        {
            business_id:str
            stars:str
            name:str
            city:str
            address:str
        }
    """
    
    # choose random city if no city is given
    if not city:
        city = random.choice(CITIES)
              
    # create dataframe with businesses 
    df = pd.DataFrame(BUSINESSES[city])
        
    similarities = dict()
    
    # calculate similarities
    for item in df.index:
        if not business_id == df.loc[item]['business_id']:
            similarities[df.loc[item]['business_id']] = similarity(business_id, df.loc[item]['business_id'], df)
    
    # create list of similarities for top n recommended businesses
    similarity_list = sorted(similarities.items(), key = lambda x: x[1], reverse = True)[:n]
    
    recommendation = []
    required_values = ['business_id', 'stars', 'name', 'city', 'address']
    
    # create a dictionary with usefull data for every recommended business
    for tuple_x, tuple_y in similarity_list:
        
        dictionary = dict()
                
        for item in df.index:
            if df.loc[item]['business_id'] == tuple_x:
                for value in required_values:
                    dictionary[value] = str(df.loc[item][value])        
        
        recommendation.append(dictionary)
        
    return recommendation


# test
recommend(business_id = 'ol2r325YnfuHcq7yeO3vdg')
# Out:
# [{'business_id': 'TL-D_z9E1eKJQqSioemFfw',
#   'stars': '3.0',
#   'name': 'Subway',
#   'city': 'Sun City',
#   'address': '10050 W Bell Rd, Ste 12'},
#  {'business_id': '8EIZAb0knT2u_z2gIxllXw',
#   'stars': '2.5',
#   'name': "Filiberto's Mexican Food",
#   'city': 'Sun City',
#   'address': '10777 Grand Ave'},
#  {'business_id': 'VPI3wxA8O2ITnt43BbhNUg',
#   'stars': '2.5',
#   'name': 'Dairy Queen',
#   'city': 'Sun City',
#   'address': '10799 Grand Ave'},
#  {'business_id': '00so-3NuawQ98XKLPMVFLg',
#   'stars': '2.0',
#   'name': 'La Petite Cafe',
#   'city': 'Sun City',
#   'address': '10503 W Thunderbird Blvd'},
#  {'business_id': '-HbTh_spJOeyEbdj4geK2Q',
#   'stars': '3.0',
#   'name': 'Jack in The Box',
#   'city': 'Sun City',
#   'address': '9906 W Thunderbird Blvd'},
#  {'business_id': 'O4TYqnhpXpyrgJBkucaeaw',
#   'stars': '1.5',
#   'name': 'KFC',
#   'city': 'Sun City',
#   'address': '10661 Grand Ave'},
#  {'business_id': 'HpIiNQwjz6ZAFyf96u9WZA',
#   'stars': '1.5',
#   'name': 'Taco Bell',
#   'city': 'Sun City',
#   'address': '10661 Grand Avenue'},
#  {'business_id': '6CpAWkTcqqNtGAfOsPeFUw',
#   'stars': '3.5',
#   'name': "Arby's",
#   'city': 'Sun City',
#   'address': '17032 N 99th Ave'},
#  {'business_id': 'GGF7Ov16JXcfGXna6BWSPg',
#   'stars': '2.5',
#   'name': "McDonald's",
#   'city': 'Sun City',
#   'address': '10040 W Bell Rd'},
#  {'business_id': 'rIhu4bA2CmSicOSJmTpGug',
#   'stars': '4.0',
#   'name': 'New York West Pastry & Bake Shop',
#   'city': 'Sun City',
#   'address': '10101 Grand Ave'}]
